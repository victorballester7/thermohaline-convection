# %%
import numpy as np
import matplotlib.pyplot as plt
with open('test_file', 'r') as f:
    all_velocities = np.loadtxt(f)
    u = all_velocities[:len(all_velocities)//4,:]
    v = all_velocities[len(all_velocities)//4:2*len(all_velocities)//4,:]
    delta_temperature = all_velocities[2*len(all_velocities)//4:3*len(all_velocities)//4,:]
    delta_salinity = all_velocities[3*len(all_velocities)//4:,:]
